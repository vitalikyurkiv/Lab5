# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df =pd.read_csv('heart_disease_uci.csv')
df.head()
# Out:
#    id  age     sex    dataset               cp  trestbps   chol    fbs  \
# 0   1   63    Male  Cleveland   typical angina     145.0  233.0   True
# 1   2   67    Male  Cleveland     asymptomatic     160.0  286.0  False
# 2   3   67    Male  Cleveland     asymptomatic     120.0  229.0  False
# 3   4   37    Male  Cleveland      non-anginal     130.0  250.0  False
# 4   5   41  Female  Cleveland  atypical angina     130.0  204.0  False
#
#           restecg  thalch  exang  oldpeak        slope   ca  \
# 0  lv hypertrophy   150.0  False      2.3  downsloping  0.0
# 1  lv hypertrophy   108.0   True      1.5         flat  3.0
# 2  lv hypertrophy   129.0   True      2.6         flat  2.0
# 3          normal   187.0  False      3.5  downsloping  0.0
# 4  lv hypertrophy   172.0  False      1.4    upsloping  0.0
#
#                 thal  num
# 0       fixed defect    0
# 1             normal    2
# 2  reversable defect    1
# 3             normal    0
# 4             normal    0

# %%
df.hist(figsize=(20, 8))
# Out:
# array([[<Axes: title={'center': 'id'}>, <Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'trestbps'}>],
#        [<Axes: title={'center': 'chol'}>,
#         <Axes: title={'center': 'thalch'}>,
#         <Axes: title={'center': 'oldpeak'}>],
#        [<Axes: title={'center': 'ca'}>, <Axes: title={'center': 'num'}>,
#         <Axes: >]], dtype=object)

# %%
print("Size of dataset:", df.shape)
print("\nIs Null")
missing_data = df.isna().sum()
print(missing_data, "\n")

print("\nIs 0")
zero_data = (df == 0).sum()
print(zero_data)
# Out:
# Size of dataset: (920, 16)
#
# Is Null
# id            0
# age           0
# sex           0
# dataset       0
# cp            0
# trestbps     59
# chol         30
# fbs          90
# restecg       2
# thalch       55
# exang        55
# oldpeak      62
# slope       309
# ca          611
# thal        486
# num           0
# dtype: int64
#
#
# Is 0
# id            0
# age           0
# sex           0
# dataset       0
# cp            0
# trestbps      1
# chol        172
# fbs         692
# restecg       0
# thalch        0
# exang       528
# oldpeak     370
# slope         0
# ca          181
# thal          0
# num         411
# dtype: int64

# %%
df_cleaned = df.copy()

# Замінити 0 на Null у вказаних колонках
columns_to_replace_zero = ['trestbps', 'chol', 'restecg', 'thalch', 'oldpeak']
for col in columns_to_replace_zero:
    df_cleaned.loc[df_cleaned[col] == 0, col] = pd.NA

# Замінити всі негативні значення на Null в колонці oldpeak
df_cleaned.loc[df_cleaned['oldpeak'] < 0, 'oldpeak'] = pd.NA

# %%
def detect_outliers(data, col, trheshold=3):
    mean = data[col].mean()
    std = data[col].std()
    
    up_bound = mean + trheshold * std
    low_bound = mean - trheshold * std
    
    anomalies = pd.concat([data[col] > up_bound, data[col] < low_bound], axis=1).any(axis=1)
    return anomalies, up_bound, low_bound

outlier_results = {}


numeric_columns = df.select_dtypes(include=['number'])

for col in numeric_columns.columns:
    anomalies, upper_bound, lower_bound = detect_outliers(df, col)
    outlier_results[col] = {
        "anomalies": anomalies,
        "upper_bound": upper_bound,
        "lower_bound": lower_bound
    }
    
    # Виведення результатів для кожного стовпця
    print(f"Column: {col}")
    print(f"Upper bound: {upper_bound}")
    print(f"Lower bound: {lower_bound}")
    print(f"Anomalies: {anomalies.sum()}") # Кількість аномалій
    print(anomalies[anomalies].index) # Індекси аномалій
    print()  # Додатковий рядок для візуального розділення результатів
# Out:
# Column: id
# Upper bound: 1257.6762665809865
# Lower bound: -336.6762665809865
# Anomalies: 0
# Index([], dtype='int64')
#
# Column: age
# Upper bound: 81.78492519394797
# Lower bound: 25.23681393648682
# Anomalies: 0
# Index([], dtype='int64')
#
# Column: trestbps
# Upper bound: 189.3306127369471
# Lower bound: 74.93419562542226
# Anomalies: 8
# Index([126, 188, 338, 548, 680, 701, 753, 896], dtype='int64')
#
# Column: chol
# Upper bound: 531.4727681383432
# Lower bound: -133.21209398103986
# Anomalies: 2
# Index([152, 546], dtype='int64')
#
# Column: thalch
# Upper bound: 215.32449421827715
# Lower bound: 59.76683526149161
# Anomalies: 0
# Index([], dtype='int64')
#
# Column: oldpeak
# Upper bound: 4.152466623827468
# Lower bound: -2.3948908662517105
# Anomalies: 7
# Index([91, 123, 183, 191, 285, 589, 615], dtype='int64')
#
# Column: ca
# Upper bound: 3.483334442210705
# Lower bound: -2.1305836331492167
# Anomalies: 0
# Index([], dtype='int64')
#
# Column: num
# Upper bound: 4.423732383927154
# Lower bound: -2.432428036101067
# Anomalies: 0
# Index([], dtype='int64')

# %%
def replace_anomalies(data, col, threshold=3):
    anomalies, _, _ = detect_outliers(data, col, threshold)
    # Заміна аномалій на NaN (Null)
    data.loc[anomalies, col] = pd.NA
    # Повернення зміненого DataFrame
    return data

# Заміна аномалій для кожного числового стовпця
for col in numeric_columns.columns:
    df_cleaned = replace_anomalies(df_cleaned, col)

# Після заміни аномалій, знову перевірте наявність аномалій
for col in numeric_columns.columns:
    anomalies, upper_bound, lower_bound = detect_outliers(df_cleaned, col)
    
    print(f"Column: {col}")
    print(f"Upper bound: {upper_bound}")
    print(f"Lower bound: {lower_bound}")
    print(f"Anomalies: {anomalies.sum()}") # Кількість аномалій
    print(anomalies[anomalies].index) # Індекси аномалій
    print()  # Додатковий рядок для візуального розділення результатів
# Out:
# Column: id
# Upper bound: 1257.6762665809865
# Lower bound: -336.6762665809865
# Anomalies: 0
# Index([], dtype='int64')
#
# Column: age
# Upper bound: 81.78492519394797
# Lower bound: 25.23681393648682
# Anomalies: 0
# Index([], dtype='int64')
#
# Column: trestbps
# Upper bound: 184.80537539658687
# Lower bound: 78.72100209462062
# Anomalies: 1
# Index([700], dtype='int64')
#
# Column: chol
# Upper bound: 397.8283241607504
# Lower bound: 89.85899978291158
# Anomalies: 6
# Index([48, 121, 181, 373, 473, 566], dtype='int64')
#
# Column: thalch
# Upper bound: 215.32449421827715
# Lower bound: 59.76683526149161
# Anomalies: 0
# Index([], dtype='int64')
#
# Column: oldpeak
# Upper bound: 4.279789686817894
# Lower bound: -1.108965162504997
# Anomalies: 1
# Index([285], dtype='int64')
#
# Column: ca
# Upper bound: 3.483334442210705
# Lower bound: -2.1305836331492167
# Anomalies: 0
# Index([], dtype='int64')
#
# Column: num
# Upper bound: 4.423732383927154
# Lower bound: -2.432428036101067
# Anomalies: 0
# Index([], dtype='int64')

# %%
numeric_data = df_cleaned.select_dtypes(include=['number'])

# Обчислення кореляції між числовими стовпцями
corr = numeric_data.corr()

corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_5f2d5_row0_col0, #T_5f2d5_row1_col1, #T_5f2d5_row2_col2, #T_5f2d5_row3_col3, #T_5f2d5_row4_col4, #T_5f2d5_row5_col5, #T_5f2d5_row6_col6, #T_5f2d5_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_5f2d5_row0_col1, #T_5f2d5_row7_col5 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_5f2d5_row0_col2, #T_5f2d5_row2_col3 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_5f2d5_row0_col3, #T_5f2d5_row0_col4, #T_5f2d5_row4_col0, #T_5f2d5_row4_col1, #T_5f2d5_row4_col2, #T_5f2d5_row4_col3, #T_5f2d5_row4_col5, #T_5f2d5_row4_col6, #T_5f2d5_row4_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_5f2d5_row0_col5, #T_5f2d5_row7_col2 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_5f2d5_row0_col6 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_5f2d5_row0_col7 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_5f2d5_row1_col0 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_5f2d5_row1_col2 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_5f2d5_row1_col3, #T_5f2d5_row6_col4 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_5f2d5_row1_col4, #T_5f2d5_row7_col4 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_5f2d5_row1_col5, #T_5f2d5_row6_col3 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_5f2d5_row1_col6 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_5f2d5_row1_col7, #T_5f2d5_row7_col1 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_5f2d5_row2_col0, #T_5f2d5_row6_col0 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_5f2d5_row2_col1 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_5f2d5_row2_col4, #T_5f2d5_row5_col4 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_5f2d5_row2_col5, #T_5f2d5_row3_col2 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_5f2d5_row2_col6 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_5f2d5_row2_col7 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_5f2d5_row3_col0, #T_5f2d5_row3_col4 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_5f2d5_row3_col1 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_5f2d5_row3_col5 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_5f2d5_row3_col6 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_5f2d5_row3_col7 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_5f2d5_row5_col0 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_5f2d5_row5_col1 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_5f2d5_row5_col2 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_5f2d5_row5_col3 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_5f2d5_row5_col6 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_5f2d5_row5_col7 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_5f2d5_row6_col1 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_5f2d5_row6_col2 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_5f2d5_row6_col5 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_5f2d5_row6_col7 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_5f2d5_row7_col0 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_5f2d5_row7_col3 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_5f2d5_row7_col6 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# </style>
# <table id="T_5f2d5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5f2d5_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_5f2d5_level0_col1" class="col_heading level0 col1" >age</th>
#       <th id="T_5f2d5_level0_col2" class="col_heading level0 col2" >trestbps</th>
#       <th id="T_5f2d5_level0_col3" class="col_heading level0 col3" >chol</th>
#       <th id="T_5f2d5_level0_col4" class="col_heading level0 col4" >thalch</th>
#       <th id="T_5f2d5_level0_col5" class="col_heading level0 col5" >oldpeak</th>
#       <th id="T_5f2d5_level0_col6" class="col_heading level0 col6" >ca</th>
#       <th id="T_5f2d5_level0_col7" class="col_heading level0 col7" >num</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5f2d5_level0_row0" class="row_heading level0 row0" >id</th>
#       <td id="T_5f2d5_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_5f2d5_row0_col1" class="data row0 col1" >0.239301</td>
#       <td id="T_5f2d5_row0_col2" class="data row0 col2" >0.061313</td>
#       <td id="T_5f2d5_row0_col3" class="data row0 col3" >-0.030420</td>
#       <td id="T_5f2d5_row0_col4" class="data row0 col4" >-0.466427</td>
#       <td id="T_5f2d5_row0_col5" class="data row0 col5" >0.119288</td>
#       <td id="T_5f2d5_row0_col6" class="data row0 col6" >0.061433</td>
#       <td id="T_5f2d5_row0_col7" class="data row0 col7" >0.273552</td>
#     </tr>
#     <tr>
#       <th id="T_5f2d5_level0_row1" class="row_heading level0 row1" >age</th>
#       <td id="T_5f2d5_row1_col0" class="data row1 col0" >0.239301</td>
#       <td id="T_5f2d5_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_5f2d5_row1_col2" class="data row1 col2" >0.258535</td>
#       <td id="T_5f2d5_row1_col3" class="data row1 col3" >0.110978</td>
#       <td id="T_5f2d5_row1_col4" class="data row1 col4" >-0.365778</td>
#       <td id="T_5f2d5_row1_col5" class="data row1 col5" >0.093936</td>
#       <td id="T_5f2d5_row1_col6" class="data row1 col6" >0.370416</td>
#       <td id="T_5f2d5_row1_col7" class="data row1 col7" >0.339596</td>
#     </tr>
#     <tr>
#       <th id="T_5f2d5_level0_row2" class="row_heading level0 row2" >trestbps</th>
#       <td id="T_5f2d5_row2_col0" class="data row2 col0" >0.061313</td>
#       <td id="T_5f2d5_row2_col1" class="data row2 col1" >0.258535</td>
#       <td id="T_5f2d5_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_5f2d5_row2_col3" class="data row2 col3" >0.125316</td>
#       <td id="T_5f2d5_row2_col4" class="data row2 col4" >-0.103192</td>
#       <td id="T_5f2d5_row2_col5" class="data row2 col5" >0.130462</td>
#       <td id="T_5f2d5_row2_col6" class="data row2 col6" >0.075585</td>
#       <td id="T_5f2d5_row2_col7" class="data row2 col7" >0.117844</td>
#     </tr>
#     <tr>
#       <th id="T_5f2d5_level0_row3" class="row_heading level0 row3" >chol</th>
#       <td id="T_5f2d5_row3_col0" class="data row3 col0" >-0.030420</td>
#       <td id="T_5f2d5_row3_col1" class="data row3 col1" >0.110978</td>
#       <td id="T_5f2d5_row3_col2" class="data row3 col2" >0.125316</td>
#       <td id="T_5f2d5_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_5f2d5_row3_col4" class="data row3 col4" >-0.026746</td>
#       <td id="T_5f2d5_row3_col5" class="data row3 col5" >0.029240</td>
#       <td id="T_5f2d5_row3_col6" class="data row3 col6" >0.151809</td>
#       <td id="T_5f2d5_row3_col7" class="data row3 col7" >0.087772</td>
#     </tr>
#     <tr>
#       <th id="T_5f2d5_level0_row4" class="row_heading level0 row4" >thalch</th>
#       <td id="T_5f2d5_row4_col0" class="data row4 col0" >-0.466427</td>
#       <td id="T_5f2d5_row4_col1" class="data row4 col1" >-0.365778</td>
#       <td id="T_5f2d5_row4_col2" class="data row4 col2" >-0.103192</td>
#       <td id="T_5f2d5_row4_col3" class="data row4 col3" >-0.026746</td>
#       <td id="T_5f2d5_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_5f2d5_row4_col5" class="data row4 col5" >-0.101676</td>
#       <td id="T_5f2d5_row4_col6" class="data row4 col6" >-0.264094</td>
#       <td id="T_5f2d5_row4_col7" class="data row4 col7" >-0.366265</td>
#     </tr>
#     <tr>
#       <th id="T_5f2d5_level0_row5" class="row_heading level0 row5" >oldpeak</th>
#       <td id="T_5f2d5_row5_col0" class="data row5 col0" >0.119288</td>
#       <td id="T_5f2d5_row5_col1" class="data row5 col1" >0.093936</td>
#       <td id="T_5f2d5_row5_col2" class="data row5 col2" >0.130462</td>
#       <td id="T_5f2d5_row5_col3" class="data row5 col3" >0.029240</td>
#       <td id="T_5f2d5_row5_col4" class="data row5 col4" >-0.101676</td>
#       <td id="T_5f2d5_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_5f2d5_row5_col6" class="data row5 col6" >0.246564</td>
#       <td id="T_5f2d5_row5_col7" class="data row5 col7" >0.386199</td>
#     </tr>
#     <tr>
#       <th id="T_5f2d5_leve

# %%
imputer = SimpleImputer(strategy='mean')  
filled_data = imputer.fit_transform(numeric_data)

scaler = StandardScaler()
scaled_data = scaler.fit_transform(filled_data)

pca = PCA(n_components=2)

pca_result = pca.fit_transform(scaled_data)

pca_df = pd.DataFrame(data=pca_result, columns=['PC1', 'PC2'])

sns.scatterplot(x='PC1', y='PC2', data=pca_df)

plt.title('PCA Results')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()

# %%
df_cleaned.to_csv('df_cleaned.csv', index=False)
